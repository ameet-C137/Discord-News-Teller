# %% [markdown]
# <a href="https://colab.research.google.com/github/ameet-C137/Discord-News-Teller/blob/main/PandasLib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pandas library For
#
# *   handling missing values
# *   Data Standardlization
# *   Data Normalization
# *   Mining

# %%
import pandas as pd

# %%
data = {
    "cars": ['bmw', 'byd', 'suzuku', 'nami'],
    "models": ['2007', '2020', '2015', '2025'],
    "passengers": [3, 7, 2, 2]}

# %%
#convert it to dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models  passengers
# 0     bmw   2007           3
# 1     byd   2020           7
# 2  suzuku   2015           2
# 3    nami   2025           2

# %%
fruits = {
    'fruits': [1,2,3,4],
    'calories': ['100','101','102','103'],
    'name': ['apples', 'oranges', 'cherries', 'pears'],
    'season': ['spring', 'summer', 'fall', 'winter'],
    'price_kg': ['100', '400', '600', '800'],
    'popularity': ['high', 'medium', 'bad', 'good'],
    'suitable_for_dinner': [True, False, False, True]
}

d1 = pd.DataFrame(fruits)
d1
# Out:
#    fruits calories      name  season price_kg popularity  suitable_for_dinner
# 0       1      100    apples  spring      100       high                 True
# 1       2      101   oranges  summer      400     medium                False
# 2       3      102  cherries    fall      600        bad                False
# 3       4      103     pears  winter      800       good                 True
